# %% [markdown]
# 從《Python 網路爬蟲與資料分析入門實戰》第三章的範例中練習爬蟲
#
# 從第三章奇摩電影爬蟲範例中練習自己寫的程式碼
#
# 書中原始程式碼來源：https://github.com/jwlin/web-crawler-tutorial/tree/master/ch3

# %% [markdown]
# # 本周新片：(1)函數爬蟲資料並儲存(2)爬蟲兩頁的資料並儲存

# %% [markdown]
# ## 1-1爬蟲函數：將奇摩本周新片的資料抓下來

# %%
import requests
import re
from bs4 import BeautifulSoup

url='https://movies.yahoo.com.tw/movie_thisweek.html'

def yahoo_newmovie(url):
    #1.與網頁溝通/連線(使用requests套件)
    resp = requests.get(url)
    #2.剖析網頁原始碼(使用BeautifulSoup剖析器) 
    soup = BeautifulSoup(resp.text, 'html5lib')
    #3.取得網頁內容：3.1電影主資訊的位置
    rows = soup.find_all('div', 'release_info_text')
        #3.2.創造空清單變數存放所有資訊
    movies = []
        #3.3.迴圈跑電影資訊的內容
    for row in rows:
        #3.4.創造空的字典存放每個電影資訊
        movie = dict()
        #3.5.創造中文電影名稱存放電影的「中文名稱」:div標籤/release_movie_name屬性/a標籤
        movie['ch_name'] = row.find('div', 'release_movie_name').a.text.strip()
        #3.5.創造「英文名稱」:div標籤/release_movie_name屬性中的div標籤/en屬性/a標籤
        movie['eng_name'] = row.find('div', 'release_movie_name').find('div', 'en').a.text.strip()
            ##3.5.1.創造符合上映日期的格式(三組一或多個數字)
        pattern = '\d+-\d+-\d+'
            ##3.5.2.將上映日期位置(div標籤/release_movie_time屬性)的內容放入匹配格式的re.search套件中
        match = re.search(pattern,row.find('div', 'release_movie_time').text)
            ##3.5.2創造「上映日期」:將符合格式的內容放入
        movie['release_date'] = match.group(0)
        #3.6創造「期待值」:div標籤/leveltext屬性/span標籤
        movie['expectation'] = row.find('div', 'leveltext').span.text.strip()
        #3.7創造「電影網址」:div標籤/release_movie_name屬性/a標籤的href
        movie['url'] = row.find('div', 'release_movie_name').a['href']
        #3.8創造「電影ID」:從電影網址中去除.html,再分隔-取出最右邊的電影ID
        movie['movie_id'] =movie['url'].split('.html')[0].split('-')[-1]
        #3.9創造「預告網址」:主資訊的父節點的前一個兄弟節點的div標籤/release_foto屬性/a標籤的img的src
        movie['poster_url'] = row.parent.find_previous_sibling('div', 'release_foto').a.img['src']
        #3.10t創造「簡介」:div標籤/release_text屬性並取代\n
        movie['intro'] = row.find('div', 'release_text').text.replace('\n', '').strip()
        #3.11創造變項trailer_a放入預告片網址位置:div標籤/release_btn color_btnbox屬性的所有第二個a標籤
        trailer_a = row.find_next_sibling('div', 'release_btn color_btnbox').find_all('a')[1]
            #3.11.1創造「預告片網址」：如果href有在變項中就放入變項的href內容，沒有則填入空白
        movie['trailer_url'] = trailer_a['href'] if 'href' in trailer_a.attrs.keys() else ''
        #3.12將上述資料添加到movies中
        movies.append(movie)
        #3.13返回所有電影資訊的變項
    return movies
yahoo_newmovie(url)
# Out:
# [{'ch_name': '賽道狂人',
#   'eng_name': 'Ford v Ferrari',
#   'expectation': '78%',
://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/November2019/YThUSgl1zkdp5KHXcQQB-800x1142.jpg',
#   'release_date': '2019-11-29',
#   'trailer_url': 'https://movies.yahoo.com.tw/video/%E6%9A%B4%E8%B5%B0%E6%9B%BC%E5%93%88%E9%A0%93-%E5%B9%95%E5%BE%8C%E8%8A%B1%E7%B5%AE-133617952.html?movie_id=10044',
#   'url': 'https://movies.yahoo.com.tw/movieinfo_main/%E6%9A%B4%E8%B5%B0%E6%9B%BC%E5%93%88%E9%A0%93-21-bridges-10044'},
#  {'ch_name': '布魯克林孤兒',
#   'eng_name': 'Motherless Brooklyn',
#   'expectation': '91%',
#   'intro': '萊諾艾斯洛（艾德華諾頓 飾），一名患有妥瑞症的孤獨私家偵探，他的良師和唯一朋友法蘭克敏納（布魯斯威利 飾）遭到謀殺，他冒著生命危險設法破案。他手上只有寥寥無幾的線索，不過他滿懷衝勁，解開了層層掩飾的重大祕密，而那攸關著能否讓紐約市維持和諧的命運。在一連串的神祕事件中，他從哈林區醉生夢死的爵士俱樂部，來到布魯克林區邊緣化的貧民窟，最後來到紐約權力經紀人的陣地，萊諾必須對付流氓、腐敗和全市最危險的人，為的只是向他的朋友致敬，並拯救可能會讓他獲得救贖的女人。\xa0【關於電影】\xa0《布魯克林孤兒》由奧斯卡獎提名者艾德華諾頓（《鳥人》、《美國X檔案》、《驚悚》）自編自導自製自演。這部電影搬上大銀幕的旅程始於1999年，當時艾德華諾頓發現強納森列瑟（Jonathan Lethem）的同名小說及其令人難忘的中心角色拍成電影的可能性，但他的目標是將這個故事裡的當代角色置換到不同的時代和情節，賦予其獨特的氛圍，重新設定成1950年代的背景，這時紐約市正面臨重大的改變。\xa0\xa0星光熠熠的卡司包括艾德華諾頓、布魯斯威利（《終極警探》系列、《月昇冒險王國》）、古古瑪芭塔勞（《時間的皺摺》）、巴比卡納佛（《老娘叫譚雅》）、崔莉瓊斯（《被抹滅的男孩》）、麥克威廉斯（《別人眼中的我們》）、萊絲里曼恩（《婦仇者聯盟》）、伊森索普（《華爾街之狼》）、達拉斯羅伯茲（《藥命俱樂部》）、喬許派斯（影集《清道夫》）、羅伯雷威斯頓（影集《修正罪案》）、費雪史帝夫（影集《諜海黑名單》），還有奧斯卡獎提名男演員亞歷鮑德溫（《鬼牌逆轉勝》、《黑色黨徒》、《神鬼無間》）和奧斯卡獎提名男演員威廉達佛（《梵谷：在永恆之門》、《歡迎光臨奇幻城堡》）。',
#   'movie_id': '10224',
#   'poster_url': 'https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/November2019/p1bumxGRyhTIuwShxpHs-800x1151.jpg',
#   'release_date': '2019-11-29',
#   'trailer_url': 'https://movies.yahoo.com.tw/video/%E5%B8%83%E9%AD%AF%E5%85%8B%E6%9E%97%E5%AD%A4%E5%85%92-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-030939052.html?movie_id=10224',
#   'url': 'https://movies.yahoo.com.tw/movieinfo_main/%E5%B8%83%E9%AD%AF%E5%85%8B%E6%9E%97%E5%AD%A4%E5%85%92-motherless-brooklyn-10224'},
#  {'ch_name': '懸案密碼前傳：瓶中信',
#   'eng_name': 'A Conspiracy Of Faith',
#   'expectation': '92%',
#   'intro': '★系列偵探小說包辦AMAZON總榜前三名超過130週★系列電影上映全球為之震撼★系列小說全球銷售突破1500萬冊★《龍紋身的女孩》製作團隊重金打造★影評高分評價 全球書迷引頸期盼\xa0一個裝著一張陳舊信紙的瓶子在日德蘭半島被發現，從很久之前經過長距離的漂流來到這裡，無意間被打撈上岸信上的訊息難以解讀，直到一名調查人員無意間看出信件開頭用丹麥文寫著：「救命」。 求救信傳回丹麥後由懸案組負責調查，但在海水與時間的磨蝕下，信中以鮮血書寫的字跡大多變得模糊難辨，一場宛如文字解謎遊戲的辦案過程也火速展開，兩人被捲入一起驚悚的案件涉及一位精神病殺人犯，宗教狂熱及手足劫持事件，但他們的父母卻從不曾報案，這引起了卡爾與阿薩德注意，這究竟是父母狠心所為還是另有其不可告人的祕密？',
#   'movie_id': '10254',
#   'poster_url': 'https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/September2019/OCsHeE0jM5w54PN2ndGY-800x1185.jpg',
#   'release_date': '2019-11-29',
#   'trailer_url': 'https://movies.yahoo.com.tw/video/%E6%87%B8%E6%A1%88%E5%AF%86%E7%A2%BC%E5%89%8D%E5%82%B3-%E7%93%B6%E4%B8%AD%E4%BF%A1-%E7%B7%9D%E9%AD%94%E7%AF%87-065336116.html?movie_id=10254',
#   'url': 'https://movies.yahoo.com.tw/movieinfo_main/%E6%87%B8%E6%A1%88%E5%AF%86%E7%A2%BC%E5%89%8D%E5%82%B3-%E7%93%B6%E4%B8%AD%E4%BF%A1-a-conspiracy-of-faith-10254'},
#  {'ch_name': '寂寞診療室',
#   'eng_name': 'Sibyl',
#   'expectation': '53%',
#   'intro': '★2019年坎城影展主競賽片\xa0★凱薩獎提名女導最新力作 柏林、凱薩獎影帝后同台飆戲★繆斯女神的失序人生 激發出最黑暗自我！★為愛狂亂 情慾解放媲美《藍色是最溫暖的顏色》★誰不是一邊享受寂寞 一邊渴望被愛？★《我的哈比情人》薇吉妮愛菲亞 X《藍色是最溫暖的顏色》阿黛兒艾薩卓普洛斯 X《不過就是世界末日》影帝 加斯帕德尤利爾X《顛父人生》影后 桑德拉惠勒X《幻想戀愛》尼斯許奈德 重量卡司演技狂飆\xa0厭倦諮商工作的心理治療師西碧兒（薇吉妮愛菲亞 飾）一心想重操寫作舊業，轉而成為一名小說家，因此拒絕許多前來求診的病患，但禁不起焦慮不安的新銳演員瑪格（阿黛兒艾薩卓普洛斯 飾）一再請求而接受她的看診。然而，在諮商過程中，意氣消沉的西碧兒卻逐漸著迷於瑪格狂亂動盪的人生，視瑪格為寫作的靈感泉源，不僅愈來愈涉入瑪格的生活，自己的生活也逐漸失序……。',
#   'movie_id': '10282',
#   'poster_url': 'https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/November2019/hPg8YWGufMEIEhRcjlAQ-1024x1458.jpg',
#   'release_date': '2019-11-29',
#   'trailer_url': 'https://movies.yahoo.com.tw/video/%E5%AF%82%E5%AF%9E%E8%A8%BA%E7%99%82%E5%AE%A4-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A
衛非凡的超現實短片《安達魯之犬》（Un Chien Andalou）。片中的「剃刀割眼」躍上影史經典畫面，一戰成名。1930年，布紐爾再度和達利聯手，創作出《黃金年代》（L’Age d’Or）。狂野如夢的手法，一舉敲開文明社會的荒誕與虛假。布紐爾因此被米高梅發掘，遠赴好萊塢發展。然而堅持創作自由的他，很快就選擇毀約飛回巴黎，準備拍攝他人生中、也是影史上，最獨一無二的紀錄片：《無糧之地》（Las Hurdes）。\xa0顛覆心靈意識的影像語言1933年，《無糧之地》在西班牙試映後隨即被政府禁演，甚至指示各國的大使館不准讓這部片在國外上映。直到1937年西班牙內戰期間，這部紀錄片才在法國上映，但很快又被禁演。片中有不少爭議鏡頭，比如：活扯雞頭、開槍逼山羊墜崖、讓驢子遭蜂群叮咬。為了將死亡引導到鏡頭面前，布紐爾押上靈魂，冷血操控著現實。然而就是這複雜難解的面向，讓我們更有機會直面人性的盲點。\xa0導演薩爾瓦多．西莫（Salvador Simó）表示：「我們想告訴觀眾的訊息是，這些事是真的發生過，並不是我們發明的。我希望人們可以思考，我們都很擔心動物，但或許我們也該更擔心正發生在其他人類身上的事情。」',
#   'movie_id': '10334',
#   'poster_url': 'https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/October2019/znIFJU0EJOUSdKr0qLnQ-504x720.jpg',
#   'release_date': '2019-11-29',
#   'trailer_url': 'https://movies.yahoo.com.tw/video/%E5%B8%83%E7%B4%90%E7%88%BE%E8%B6%85%E7%8F%BE%E5%AF%A6%E4%BA%BA%E7%94%9F-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-030619711.html?movie_id=10334',
#   'url': 'https://movies.yahoo.com.tw/movieinfo_main/%E5%B8%83%E7%B4%90%E7%88%BE%E8%B6%85%E7%8F%BE%E5%AF%A6%E4%BA%BA%E7%94%9F-bunuel-in-the-labyrinth-of-the-turtles-10334'},
#  {'ch_name': '怪奇超自然',
#   'eng_name': 'Strange Nature',
#   'expectation': '88%',
#   'intro': '★《雷神索爾》《2012》幕後團隊顫慄打造全新品種恐怖片★環境汙染加上畸形突變物種，宛如《永不妥協》碰上《撕裂人》★平靜池水，暗藏殺機\xa0改編自真實未解之謎，1995年，明尼蘇達州的池塘開始出現畸形青蛙的蹤跡，往後幾年，數以千計的畸形青蛙陸續被發現，有關當局只能推測河水中含有某種物質引發青蛙突變。然而這樣的狀況同樣也出現在印度和中國，至於發生的原因至今仍是個謎團……\xa0本片描述一名單親母親和她的11歲兒子居住的小鎮，某日開始陸續發現畸形生物，隨著情況越演越烈，更兇殘的突變物種早已悄悄來到鎮上…',
#   'movie_id': '10338',
#   'poster_url': 'https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/November2019/RwmO4O6jNlakGHd4XHBv-760x1280.jpg',
#   'release_date': '2019-11-29',
#   'trailer_url': 'https://movies.yahoo.com.tw/video/%E6%80%AA%E5%A5%87%E8%B6%85%E8%87%AA%E7%84%B6-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-082852291.html?movie_id=10338',
#   'url': 'https://movies.yahoo.com.tw/movieinfo_main/%E6%80%AA%E5%A5%87%E8%B6%85%E8%87%AA%E7%84%B6-strange-nature-10338'}]

# %% [markdown]
# ##  1-2整理爬下來的資料(dataframe)並印出資料筆數與期待值高的電影

# %%
import pandas as pd
import numpy as np

#4.將本周新片整理成dataframe,印出符合條件的電影並儲存成csv檔
    #4.1用函數取出所有資料
data=yahoo_newmovie(url)
    #4.2命名各個欄位順序(不命名則會照開頭字母順序)
name=['ch_name','eng_name','release_date','expectation','url','movie_id','poster_url','intro','trailer_url']
    #4.3將資料轉成dataframe
test=pd.DataFrame(columns=name,data=data)
    #4.4整理資料中的索引(從1開始編號)
test.index = np.arange(1,len(test)+1)
    #4.5將索引重新命名成電影編號
test.index.names = ['movie_NO.']
    #4.6顯示資料量(共有幾部電影)
print('本周新片', len(data), '部電影')
    #4.7顯示期待值超過90%的電影名稱
print('期待值> 90% :' )
n='90%'
for a in data:
    if a['expectation'] > n :
        print(a['ch_name'],a['expectation'])
# Out:
# 本周新片 9 部電影
# 期待值> 90% :
# 布魯克林孤兒 91%
# 懸案密碼前傳：瓶中信 92%
# 夕霧花園 95%

# %% [markdown]
# ## 1-3印出所有資料並儲存成csv檔

# %%
    #4.8印出所有電影
print('本周新片:',test)
    #4.9儲存成csv檔案
test.to_csv('newmovie.csv',encoding='utf_8_sig')
# Out:
# 本周新片:               ch_name                                eng_name release_date  \
# movie_NO.
# 1                賽道狂人                          Ford v Ferrari   2019-11-28
# 2                鋒迴路轉                              Knives Out   2019-11-28
# 3               暴走曼哈頓                              21 Bridges   2019-11-29
# 4              布魯克林孤兒                     Motherless Brooklyn   2019-11-29
# 5          懸案密碼前傳：瓶中信                   A Conspiracy Of Faith   2019-11-29
# 6               寂寞診療室                                   Sibyl   2019-11-29
# 7                夕霧花園             The Garden of Evening Mists   2019-11-29
# 8            布紐爾超現實人生  Buñuel in the Labyrinth of the Turtles   2019-11-29
# 9               怪奇超自然                          Strange Nature   2019-11-29
#
#           expectation                                                url  \
# movie_NO.
# 1                 78%  https://movies.yahoo.com.tw/movieinfo_main/%E8...
# 2                 87%  https://movies.yahoo.com.tw/movieinfo_main/%E9...
# 3                 82%  https://movies.yahoo.com.tw/movieinfo_main/%E6...
# 4                 91%  https://movies.yahoo.com.tw/movieinfo_main/%E5...
# 5                 92%  https://movies.yahoo.com.tw/movieinfo_main/%E6...
# 6                 53%  https://movies.yahoo.com.tw/movieinfo_main/%E5...
# 7                 95%  https://movies.yahoo.com.tw/movieinfo_main/%E5...
# 8                 42%  https://movies.yahoo.com.tw/movieinfo_main/%E5...
# 9                 88%  https://movies.yahoo.com.tw/movieinfo_main/%E6...
#
#           movie_id                                         poster_url  \
# movie_NO.
# 1            10097  https://movies.yahoo.com.tw/x/r/w420/i/o/produ...
# 2            10258  https://movies.yahoo.com.tw/x/r/w420/i/o/produ...
# 3            10044  https://movies.yahoo.com.tw/x/r/w420/i/o/produ...
# 4            10224  https://movies.yahoo.com.tw/x/r/w420/i/o/produ...
# 5            10254  https://movies.yahoo.com.tw/x/r/w420/i/o/produ...
# 6            10282  https://movies.yahoo.com.tw/x/r/w420/i/o/produ...
# 7            10327  https://movies.yahoo.com.tw/x/r/w420/i/o/produ...
# 8            10334  https://movies.yahoo.com.tw/x/r/w420/i/o/produ...
# 9            10338  https://movies.yahoo.com.tw/x/r/w420/i/o/produ...
#
#                                                        intro  \
# movie_NO.
# 1          ★集結影壇夢幻卡司！麥特戴蒙聯手克里斯汀貝爾 重現賽車史經典戰役★年度熱血鉅作《賽道狂人》爛...
# 2          ★ 《STAR WARS：最後的絕地武士》原班團隊犯罪懸疑鉅獻★ 導演萊恩強生重返拿手類型，...
# 3          ★ 《黑豹》查德維克博斯曼 自製自演化身犯罪剋星 脫下戰袍 一樣英勇！ ★ 《復仇者聯盟4：...
# 4          萊諾艾斯洛（艾德華諾頓 飾），一名患有妥瑞症的孤獨私家偵探，他的良師和唯一朋友法蘭克敏納（布...
# 5          ★系列偵探小說包辦AMAZON總榜前三名超過130週★系列電影上映全球為之震撼★系列小說全球...
# 6          ★2019年坎城影展主競賽片 ★凱薩獎提名女導最新力作 柏林、凱薩獎影帝后同台飆戲★繆斯女神...
# 7          ★第56屆金馬獎最佳劇情長片、導演、女主角、原創音樂、攝影、剪輯、改編劇本、造型、美術等9項...
# 8          ★超現實主義電影之父真實故事改編★榮獲安錫國際動畫影展雙料大獎肯定 歡迎踏上　海龜迷宮般的光...
# 9          ★《雷神索爾》《2012》幕後團隊顫慄打造全新品種恐怖片★環境汙染加上畸形突變物種，宛如《永...
#
#                                                  trailer_url
# movie_NO.
# 1          https://movies.yahoo.com.tw/video/%E8%B3%BD%E9...
# 2          https://movies.yahoo.com.tw/video/%E9%8B%92%E8...
# 3          https://movies.yahoo.com.tw/video/%E6%9A%B4%E8...
# 4          https://movies.yahoo.com.tw/video/%E5%B8%83%E9...
# 5          https://movies.yahoo.com.tw/video/%E6%87%B8%E6...
# 6          https://movies.yahoo.com.tw/video/%E5%AF%82%E5...
# 7          https://movies.yahoo.com.tw/video/%E5%A4%95%E9...
# 8          https://movies.yahoo.com.tw/video/%E5%B8%83%E7...
# 9          https://movies.yahoo.com.tw/video/%E6%80%AA%E5...

# %% [markdown]
# ## 2-1若本周新片有兩頁的資料

# %% [markdown]
# 若本周新片沒有第二頁資料則會Error,先用上映中的電影網址代替

# %%
import requests
import re
from bs4 import BeautifulSoup

##用上映中的電影網址做範例
url='https://movies.yahoo.com.tw/movie_intheaters.html'    
#將第二頁網頁的電影內容加入(知道搜尋結果只有兩頁的程式碼)

    #創造空清單變數存放所有資訊
movies=[]
    #用函數爬出第一頁內容
movie=yahoo_newmovie(url)
    #將第一頁內容加入變數中
movies += movie
    #向第一頁搜尋網頁發出請求
resp = requests.get(url)
    #剖析原始碼
soup = BeautifulSoup(resp.text, 'html5lib')
    #如果有下一頁的網址則儲存下一頁的內容
if soup.find('li', 'nexttxt').a['href']:
    #創造下一頁的網址變數
    nextpage = soup.find('li', 'nexttxt').a['href']
    #將下一頁內容爬出來
    new_movie=yahoo_newmovie(nextpage)
    #將新的內容儲存至清單變數中
    movies += new_movie
        
import pandas as pd
import numpy as np

#將本周新片整理成dataframe,印出符合條件的電影並儲存成csv檔
    #用函數取出所有資料
data=movies
    #命名各個欄位順序(不命名則會照開頭字母順序)
name=['ch_name','eng_name','release_date','expectation','url','movie_id','poster_url','intro','trailer_url']
    #將資料轉成dataframe
test=pd.DataFrame(columns=name,data=data)
    #整理資料中的索引(從1開始編號)
test.index = np.arange(1,len(test)+1)
    #將索引重新命名成電影編號
test.index.names = ['movie_NO.']
    #顯示資料量(共有幾部電影)
print('本周新片', len(data), '部電影')
    #顯示期待值超過90%的電影名稱
print('期待值> 90% :' )
n='90%'
for a in data:
    if a['expectation'] > n :
        print(a['ch_name'],a['expectation'])
    #4.8印出所有電影
print('本周新片:',test)
    #4.9儲存成csv檔案
test.to_csv('newmovie.csv',encoding='utf_8_sig')
# Out:
# 本周新片 20 部電影
# 期待值> 90% :
# 冰雪奇緣2 92%
# 神機有毛病 95%
# 萬萬沒想到 97%
# 11         https://movies.yahoo.com.tw/video/%E5%86%B0%E9...
# 12         https://movies.yahoo.com.tw/video/%E6%96%B0%E8...
# 13         https://movies.yahoo.com.tw/video/%E7%82%BA%E7...
# 14         https://movies.yahoo.com.tw/video/%E5%81%B5%E7...
# 15         https://movies.yahoo.com.tw/video/%E7%A5%9E%E6...
# 16         https://movies.yahoo.com.tw/video/%E8%90%AC%E8...
# 17         https://movies.yahoo.com.tw/video/%E6%88%91%E7...
# 18         https://movies.yahoo.com.tw/video/%E5%A4%A7%E9...
# 19         https://movies.yahoo.com.tw/video/hello-world-...
# 20         https://movies.yahoo.com.tw/video/%E6%8A%B1%E6...

# %% [markdown]
# # 無註解程式碼

# %%
import requests
import re
from bs4 import BeautifulSoup

url='https://movies.yahoo.com.tw/movie_thisweek.html'

def yahoo_newmovie(url):
    resp = requests.get(url)
    soup = BeautifulSoup(resp.text, 'html5lib')
    rows = soup.find_all('div', 'release_info_text')
    movies = []
    for row in rows:
        movie = dict()
        movie['ch_name'] = row.find('div', 'release_movie_name').a.text.strip()
        movie['eng_name'] = row.find('div', 'release_movie_name').find('div', 'en').a.text.strip()
        pattern = '\d+-\d+-\d+'
        match = re.search(pattern,row.find('div', 'release_movie_time').text)
        movie['release_date'] = match.group(0)
        movie['expectation'] = row.find('div', 'leveltext').span.text.strip()
        movie['url'] = row.find('div', 'release_movie_name').a['href']
        movie['movie_id'] =movie['url'].split('.html')[0].split('-')[-1]
        movie['poster_url'] = row.parent.find_previous_sibling('div', 'release_foto').a.img['src']
        movie['intro'] = row.find('div', 'release_text').text.replace('\n', '').strip()
        trailer_a = row.find_next_sibling('div', 'release_btn color_btnbox').find_all('a')[1]
        movie['trailer_url'] = trailer_a['href'] if 'href' in trailer_a.attrs.keys() else ''
        movies.append(movie)
    return movies

import pandas as pd
import numpy as np

data=yahoo_newmovie(url)
name=['ch_name','eng_name','release_date','expectation','url','movie_id','poster_url','intro','trailer_url']
test=pd.DataFrame(columns=name,data=data)
test.index = np.arange(1,len(test)+1)
test.index.names = ['movie_NO.']

print('本周新片', len(data), '部電影')
print('期待值> 90% :' )
n='90%'
for a in data:
    if a['expectation'] > n :
        print(a['ch_name'],a['expectation'])
        

print('本周新片:',test)
test.to_csv('newmovie.csv',encoding='utf_8_sig')

# %%
import requests
import re
from bs4 import BeautifulSoup

url='https://movies.yahoo.com.tw/movie_thisweek.html'    

movies=[]
movie=yahoo_newmovie(url)
movies += movie
resp = requests.get(url)
soup = BeautifulSoup(resp.text, 'html5lib')

if soup.find('li', 'nexttxt').a['href']:
    nextpage = soup.find('li', 'nexttxt').a['href']
    new_movie=yahoo_newmovie(nextpage)
    movies += new_movie
        
        
import pandas as pd
import numpy as np

data=movies
name=['ch_name','eng_name','release_date','expectation','url','movie_id','poster_url','intro','trailer_url']
test=pd.DataFrame(columns=name,data=data)
test.index = np.arange(1,len(test)+1)
test.index.names = ['movie_NO.']

print('本周新片', len(data), '部電影')

print('期待值> 90% :' )
n='90%'
for a in data:
    if a['expectation'] > n :
        print(a['ch_name'],a['expectation'])
        
print('本周新片:',test)

test.to_csv('newmovie.csv',encoding='utf_8_sig')
