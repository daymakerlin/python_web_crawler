# %% [markdown]
# 從《Python 網路爬蟲與資料分析入門實戰》第三章的範例中練習爬蟲
#
# 此為第三章中批踢踢八卦版爬蟲範例中練習自寫程式碼
#
# 書中原始程式碼來源：https://github.com/jwlin/web-crawler-tutorial/tree/master/ch3

# %% [markdown]
# # 壹、寫爬蟲函數：(1)抓取今日的文章內容(2)重複抓取動作並儲存

# %%
import requests
import time
from bs4 import BeautifulSoup

def Gossiping_today_pop_articles(url):
    #1.與網頁溝通/連線(使用requests套件)並帶入是否滿18歲的cookies
    resp=requests.get(url,cookies={'over18': '1'})
    
    #2.剖析網頁原始碼(使用BeautifulSoup剖析器)  
    soup=BeautifulSoup(resp.text,'html5lib')
    
    
    #3.取得該網頁的內容
        #3.1取得上一頁連結：(1)先定位上一頁連結的「大概位置」於標籤名稱div/屬性名稱btn-group btn-group-paging
    paging_div = soup.find('div', 'btn-group btn-group-paging')
        
                        ##(2)再定位「細部精確」的所在位置：找到所有a標籤中第2個a的href(網址)
    PTT_URL = 'https://www.ptt.cc'        
    prev_url = PTT_URL+paging_div.find_all('a')[1]['href']
        
        #3.2取得該網頁的文章內容：(1)設置儲存文章的變數
    articles = []
        
                            ##(2)定位文章內容的區塊：標籤名稱div/屬性名稱r-ent
    divs = soup.find_all('div', 'r-ent')
        
                            ##(3)創造一個今日的日期並符合PTT日期格式
    today = time.strftime("%m/%d").lstrip('0')

                            ##(4)使用for迴圈取得文章區塊內的所需內容
    for d in divs:
        
                            ##(5)先設置條件取得符合今日的文章：如果發文日期(位置：div標籤/date屬性)是今天
        if d.find('div', 'date').text.strip()==today:  
            
                            ##(6)取得推文數並編輯：(6.1)先設置一個為0的推文數
            push_count = 0
        
                                                ##(6.2)取得字串型態的原始推文數:位置div標籤名/nrec屬性
            push_str = d.find('div', 'nrec').text
            
                                                ##(6.3)如果原始推文存在,將字串轉為數字
            if push_str:
                try:
                    push_count = int(push_str) 
                
                                                ##如果轉換失敗表示原始推文數為文字或空白('爆'或 'X1','X2')
                                                ##空白的推文數保持為0
                except ValueError:
            
                                                ##(6.4)轉換失敗的「爆」文轉成99推文數
                    if push_str == '爆':
                        push_count = 99
                        
                                                ##(6.5)轉換失敗的「X」文轉成-10的推文數
                    elif push_str.startswith('X'):
                        push_count = -10
                        
                        
                            ##(7)取得文章連結/標題/作者並存至文章的變數中
                                    ##(7.1)如果文章存在：標籤a就是文章所在位置
            if d.find('a'):
                
                                    ##(7.2)取得文章標題：標籤a的字串
                title = d.find('a').text    
                
                                    ##(7.3)取得文章日期：div標籤/date屬性
                date= d.find('div', 'date').text
                
                                    ##(7.4)取得文章作者：標籤div屬性author的字串
                author = d.find('div', 'author').text 
                
                                    ##(7.5)取得文章網址：標籤a的href
                href = PTT_URL+d.find('a')['href']   
                
                                    ##(7.5)將上述變數儲存至文章的變數中
                articles.append({
                    'title':title,
                    'date':date,
                    'author':author,
                    'push_count':push_count,
                    'href':href})
                
                        ##(8)將程式結果返回文章內容
    return articles,prev_url


#4.取得該網頁的上一頁的文章內容(重複1.2.3的動作)
def repeat_articles(url):
    
    ##(4.1)創造放文章的變數
    articles=[]
    
    ##(4.2)利用自寫函數取得「原網頁文章內容」與「上一頁連結」
    new_articles,prev_url=Gossiping_today_pop_articles(url)
    
    ##(4.3)將原網頁內容放入變數中
    articles += new_articles
    
    ##(4.4)利用字寫函數取得的「上一頁連結」來取得「上一頁的文章內容與連結」
    new_articles, new_prev_url= Gossiping_today_pop_articles(prev_url)
    
    ##(4.5)如果「上一頁內容」不是空的=(文章日期為今日)
        ###因Gossiping_today_pop_articles函數中設定只抓取今日文章,若非今日變數則為[]
    while new_articles!=[]:
        
        ##(4.5.1)將「上一頁文章」放入變數中
        articles += new_articles
        
        ##(4.5.2)創造更新的「上一頁文章與連結」
        new_articles,new_prev_url=Gossiping_today_pop_articles(new_prev_url)
        
    ##(4.6)如果新的「上一頁內容」是空的=(文章日期非今日)則印出上述合併的所有文章內容
    else:
        return articles

# %% [markdown]
# # 貳、處理資料：(1)印出>50的今日文章 (2)所有今日文章存成csv檔案

# %%
#1.印出今日推文數>50的文章
    ##1.1將自寫函數設為文章變數
url='https://www.ptt.cc/bbs/Gossiping/index.html'
articles=repeat_articles(url)

    ##1.2印出總文章數
print('今天有', len(articles), '篇文章')

    ##1.3印出推文數>50的文章
print('熱門文章(> 50 推):' )    
for a in articles:
    if int(a['push_count']) > 50:
        print(a)
# Out:
# 今天有 918 篇文章
# 熱門文章(> 50 推):
# {'title': '[新聞] 王立強共諜案 朱立倫四個字形容', 'date': '11/25', 'author': 'nakibasara', 'push_count': 57, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574665317.A.F11.html'}
# {'title': '[爆卦] 何君堯住院時合照議員全數落選!爽!', 'date': '11/25', 'author': 'Areso', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574664254.A.4AC.html'}
# {'title': '[新聞] 蔡英文下令 國安局抵澳查王立強案', 'date': '11/25', 'author': 'makoto1982', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574663213.A.F38.html'}
# {'title': '[爆卦] 中國人推人臉辨識投票，加快開票', 'date': '11/25', 'author': 'ben1013', 'push_count': 55, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574662308.A.9CE.html'}
# {'title': '[爆卦] 向心在出境台灣時被要求配合調查', 'date': '11/25', 'author': 'amos6064', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574661568.A.DE1.html'}
# {'title': '[新聞] 又一批中國政府秘密新疆文件洩露海外', 'date': '11/25', 'author': 'scarfman', 'push_count': 57, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574661719.A.46E.html'}
# {'title': '[問卦] 鳳梨酥的霸主是誰？', 'date': '11/25', 'author': 'mikemagic88', 'push_count': 51, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574661323.A.BB1.html'}
# {'title': '[新聞] 海嘯式潰敗！港親北京建制派怨選舉不公', 'date': '11/25', 'author': 'ifulita', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574660371.A.7B8.html'}
# {'title': '[新聞] 韓國瑜批NCC 蔡英文︰共諜案不要以中國', 'date': '11/25', 'author': 'reason825', 'push_count': 66, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574659976.A.745.html'}
# {'title': '[問卦] 有沒有坐其他座位短褲妹的卦？', 'date': '11/25', 'author': 'Forthelife', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574658766.A.946.html'}
# {'title': '[新聞] 香港區選建制派大敗 環時》總編急喊：基', 'date': '11/25', 'author': 'sony1256', 'push_count': 62, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574658890.A.BFA.html'}
# {'title': '[新聞] 民進黨提案反滲透法 時力：歡迎大轉彎', 'date': '11/25', 'author': 'leftavoid', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574659102.A.800.html'}
# {'title': '[新聞] 韓國瑜扯澳洲媒體排名80 外媒驚呆', 'date': '11/25', 'author': 'amurorei', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574658372.A.9A4.html'}
# {'title': 'Re: [新聞] 泛民大勝 港區「全民公投」清除中共代理人', 'date': '11/25', 'author': 'QQmmmmmm', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574657243.A.B81.html'}
# {'title': '[新聞] 邱毅提告 柯文哲：可影響國民黨、新黨 幕', 'date': '11/25', 'author': 'johnny790218', 'push_count': 79, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574657422.A.2BB.html'}
# {'title': '[問卦] 美乳人妻女僕裝 白色蕾絲吊帶襪', 'date': '11/25', 'author': 'tsukiyomi157', 'push_count': 66, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574656805.A.5F6.html'}
# {'title': '[爆卦] 使用河北政府指定煤炭多人一氧化碳中毒', 'date': '11/25', 'author': 'KAKAii', 'push_count': 55, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574656977.A.F3F.html'}
# {'title': 'Re: [新聞] 柯粉發起廢票運動 蔡壁如：也想知道多少', 'date': '11/25', 'author': 'smallweek', 'push_count': 53, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574656229.A.7A8.html'}
# {'title': '[新聞] 蔡總統拋0到6歲國家一起養 郭台銘：樂見', 'date': '11/25', 'author': 'Asclepius', 'push_count': 69, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574656554.A.41F.html'}
# {'title': '[新聞] 稱邱毅像中共提名挨告 柯文哲：我只是白', 'date': '11/25', 'author': 'GETpoint', 'push_count': 73, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574656614.A.BBC.html'}
# {'title': 'Re: [新聞] 泛民大勝 港區「全民公投」清除中共代理人', 'date': '11/25', 'author': 'DecemberSnow', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574655634.A.6AE.html'}
# {'title': '[新聞] 政黨支持度大翻轉 民進黨首勝國民黨10%、', 'date': '11/25', 'author': 'aza0290', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574655756.A.AF9.html'}
# {'title': '[問卦] 有香港新科區議員梁凱晴的八卦嗎?', 'date': '11/25', 'author': 'CavendishJr', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574655165.A.CC1.html'}
# {'title': 'Re: [新聞] 育兒政見比拚》柯文哲諷畫餅：錢在那裡', 'date': '11/25', 'author': 'acln0816', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574654369.A.62C.html'}
# {'title': '[問卦] 其實台灣真的蠻強的吧?', 'date': '11/25', 'author': 'iverlung', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574653677.A.40B.html'}
# {'title': '[新聞] 中國1.2萬劑疫苗具愛滋抗體 新生兒恐感', 'date': '11/25', 'author': 'Aruka0924', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574652963.A.3F6.html'}
# {'title': '[新聞] 總統選舉史上最大差距 「蔡賴配」獲55.2%', 'date': '11/25', 'author': 'AllenHuang', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574653321.A.51D.html'}
# {'title': '[問卦] 廣西再次大地震，有新斷層!?', 'date': '11/25', 'author': 'GETpoint', 'push_count': 53, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574652096.A.8A9.html'}
# {'title': '[新聞] 屁孩KTV慶生嗨玩刮鬍泡！被收費竟「轟炸', 'date': '11/25', 'author': 'jim2330300', 'push_count': 58, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574651224.A.B57.html'}
# {'title': '[新聞] 澳洲情報首長：早在查中國派特工選國會', 'date': '11/25', 'author': 'CavendishJr', 'push_count': 62, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574651438.A.3CB.html'}
# {'title': '[問卦] 現在是不是要全球反中了???', 'date': '11/25', 'author': 'cytotoxic', 'push_count': 71, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574651625.A.3EC.html'}
# {'title': '[新聞] 快訊／共諜案延燒\u3000澳洲情報局長罕見發', 'date': '11/25', 'author': 'jason748', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574650973.A.BEA.html'}
# {'title': 'Fw: [討論] 新!震撼!英德配55.2 : 26.3國政配', 'date': '11/25', 'author': 'Calderon', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574650066.A.036.html'}
# {'title': '[問卦] 中國宣布香港選舉無效會怎樣', 'date': '11/25', 'author': 'csi9507121', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574650223.A.181.html'}
# {'title': '[問卦] 習近平連個香港都治理不了真廢物什麼時', 'date': '11/25', 'author': 'xzcb2008', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574649201.A.049.html'}
# {'title': 'Re: [問卦] 1450蟑螂一直帶風向說柯粉很急？', 'date': '11/25', 'author': 'F0314', 'push_count': 83, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574649675.A.BAE.html'}
# {'title': '[新聞] 韓蔡南投造勢空拍 網：沒有比較就沒有傷', 'date': '11/25', 'author': 'ccxx9999', 'push_count': 51, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574647922.A.9A9.html'}
# {'title': '[問卦] 香港選舉選完了 還會有抗中嗎？', 'date': '11/25', 'author': 'wensandra', 'push_count': 74, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574646628.A.AFF.html'}
# {'title': '[新聞] 蔡英文喊「育兒津貼加倍」\u3000侯友宜憂：新', 'date': '11/25', 'author': 'ian19940120', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574646917.A.7E5.html'}
# {'title': '[爆卦] 香港恆生指數開盤大漲300點', 'date': '11/25', 'author': 'f544544f', 'push_count': 67, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574647127.A.275.html'}
# {'title': 'Re: [新聞] 「育兒+長照」財政受得了嗎？蔡英文霸氣', 'date': '11/25', 'author': 'deann', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574645825.A.3E4.html'}
# {'title': '[新聞] 泛民大勝 港區「全民公投」清除中共代理人', 'date': '11/25', 'author': 'sunbysea', 'push_count': 57, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574645399.A.104.html'}
# {'title': '[爆卦] 地震', 'date': '11/25', 'author': 'eyeshield21', 'push_count': 52, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574645621.A.706.html'}
# {'title': '[新聞] 特斯拉車禍／北投望族少爺試駕車禍', 'date': '11/25', 'author': 'nanako24', 'push_count': 90, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574644058.A.A4C.html'}
# {'title': '[新聞] 東尼大木「性侵前輩女友」！綁手腳拖進浴', 'date': '11/25', 'author': 'chang0327', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574644489.A.21B.html'}
# {'title': '[問卦] 接下來，鄉民希望中共怎麼做？', 'date': '11/25', 'author': 'moslaa', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574644792.A.3A2.html'}
# {'title': 'Re: [新聞] 拚國會過半！蔡英文：「保守威權的法案」', 'date': '11/25', 'author': 'deann', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574642094.A.499.html'}
# {'title': '[爆卦] 何君堯輸了 有人真到維園裸跑慶祝', 'date': '11/25', 'author': 'epikpi', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574642682.A.BBA.html'}
# {'title': '[問卦] 香港9.2開始討論要移民台灣的八卦？', 'date': '11/25', 'author': 'Yui5', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574641502.A.66A.html'}
# {'title': '[新聞] 香港區選泛民派奪349席「確定掌握過半」', 'date': '11/25', 'author': 'yuzukineko', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574638826.A.68E.html'}
# {'title': 'Re: [新聞] 「王立強」是化名 中共造假法院判決書中', 'date': '11/25', 'author': 'oz5566', 'push_count': 54, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574639337.A.B12.html'}
# {'title': '[新聞] 中國人旅日不受歡迎？習近平：都是日本人', 'date': '11/25', 'author': 'ibanes', 'push_count': 53, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574640512.A.8BC.html'}
# {'title': '[新聞] 區議會選舉大慘敗！港建制派：這是場不', 'date': '11/25', 'author': 'cycling', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574640734.A.8BF.html'}
# {'title': '[爆卦] 香港黃大仙區25席全數由泛民派當選', 'date': '11/25', 'author': 'Areso', 'push_count': 67, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574637838.A.773.html'}
# {'title': '[新聞] 香港區議會選舉泛民大勝 親中建制派大敗', 'date': '11/25', 'author': 'takeshi911', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574637871.A.4C5.html'}
# {'title': '[問卦] 中共有過正面的新聞嗎？', 'date': '11/25', 'author': 'cksxxb123', 'push_count': 95, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574637908.A.C56.html'}
# {'title': '[新聞] 香港區議會選舉初步計票 泛民派領先將奪', 'date': '11/25', 'author': 'pitalvlu', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574632642.A.5C2.html'}
# {'title': '[新聞] 「王立強」是化名 中共造假法院判決書中', 'date': '11/25', 'author': 'sweat992001', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574636327.A.A68.html'}
# {'title': '[爆卦] 跟庶民總統吃飯完全免費', 'date': '11/25', 'author': 'tsungsyu', 'push_count': 75, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574629419.A.B1D.html'}
# {'title': 'Re: [問卦] 香港這次是擺西瓜都上嗎？', 'date': '11/25', 'author': 'gaucher', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574631003.A.337.html'}
# {'title': '[爆卦] 香港民主派大勝，百度全面封鎖新聞', 'date': '11/25', 'author': 'cmq29', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574623707.A.D69.html'}
# {'title': 'Re: [問卦] 說好小波浪怎麼變成大海嘯?', 'date': '11/25', 'author': 'coober', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574621672.A.780.html'}
# {'title': '[問卦] 說好小波浪怎麼變成大海嘯?', 'date': '11/25', 'author': 'boyen3', 'push_count': 66, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574620466.A.E47.html'}
# {'title': 'Re: [問卦] 如果民主派大獲全勝 中國人要怎麼辯解', 'date': '11/25', 'author': 'hewolf', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574618602.A.526.html'}
# {'title': '[爆卦] 何君堯輸了', 'date': '11/25', 'author': 'beerduck', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574616518.A.77A.html'}
# {'title': '[問卦] 如果民主派大獲全勝 中國人要怎麼辯解', 'date': '11/25', 'author': 'tavern', 'push_count': 97, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574617901.A.651.html'}
# {'title': '[問卦] 大家還有留族譜嗎', 'date': '11/25', 'author': 'qqqwsd', 'push_count': 68, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574614837.A.8D8.html'}
# {'title': '[爆卦] 香港即時開票結果目前351:45', 'date': '11/25', 'author': 'beerduck', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574613180.A.96A.html'}
# {'title': 'Re: [爆卦] 香港開票亂像四起', 'date': '11/25', 'author': 'akway', 'push_count': 54, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574612516.A.DCA.html'}
# {'title': '[新聞] 荷蘭議會通過議案：禁止違反人權的中港人士入境', 'date': '11/25', 'author': 'uilmas1', 'push_count': 86, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574612777.A.0CA.html'}
# {'title': '[問卦] 哪一首台語歌是必聽的', 'date': '11/25', 'author': 'wugucc029', 'push_count': 60, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1574611754.A.9CB.html'}

# %%
import pandas as pd
import numpy as np

#2.儲存所有今日文章
    ##2.1爬取文章
data=repeat_articles(url)

    ##2.2將資料轉成DataFrame型式(columns可不寫入，資料中列的名稱會照字母排序)
name=['title','date','author','push_count','href']
test=pd.DataFrame(columns=name,data=data)

    ##2.3把索引改成從1開始
test.index = np.arange(1,len(test)+1)
    
    ##2.4將索引名稱改為編號
test.index.names = ['article_NO.']

    ##印出結果並儲存成CSV檔案
print(test)
test.to_csv('testcsv.csv',encoding='utf_8_sig')
# Out:
#                                        title   date        author  push_count  \
# article_NO.
# 1                 Re: [問卦] 認真在看經濟學人雜誌的都是什麼人？  11/25    qqmaybenot           0
# 2                            [問卦] 到菲律賓找老婆如何？  11/25      rockon15          11
# 3                   Re: [問卦] 日本人出國比例好像沒台灣人高？  11/25      st900278           7
# 4              Re: [新聞] 韓國瑜口誤有「200個大使館」　網酸：把  11/25   ilovesumika           1
# 5                Re: [新聞] 獨家訪問／前軍情局副局長：王立強從頭  11/25        kimjay           1
# 6                  Re: [爆卦] 向心剛在出境台灣時被要求配合調查  11/25         kh749           5
# 24           https://www.ptt.cc/bbs/Gossiping/M.1574664889....
# 25           https://www.ptt.cc/bbs/Gossiping/M.1574664897....
# 26           https://www.ptt.cc/bbs/Gossiping/M.1574664995....
# 27           https://www.ptt.cc/bbs/Gossiping/M.1574665104....
# 28           https://www.ptt.cc/bbs/Gossiping/M.1574665211....
# 29           https://www.ptt.cc/bbs/Gossiping/M.1574665214....
# 30           https://www.ptt.cc/bbs/Gossiping/M.1574665225....
# ...                                                        ...
# 889          https://www.ptt.cc/bbs/Gossiping/M.1574613041....
# 890          https://www.ptt.cc/bbs/Gossiping/M.1574611682....
# 891          https://www.ptt.cc/bbs/Gossiping/M.1574611730....
# 892          https://www.ptt.cc/bbs/Gossiping/M.1574611754....
# 893          https://www.ptt.cc/bbs/Gossiping/M.1574611817....
# 894          https://www.ptt.cc/bbs/Gossiping/M.1574611864....
# 895          https://www.ptt.cc/bbs/Gossiping/M.1574611899....
# 896          https://www.ptt.cc/bbs/Gossiping/M.1574611961....
# 897          https://www.ptt.cc/bbs/Gossiping/M.1574611965....
# 898          https://www.ptt.cc/bbs/Gossiping/M.1574612002....
# 899          https://www.ptt.cc/bbs/Gossiping/M.1574612039....
# 900          https://www.ptt.cc/bbs/Gossiping/M.1574612164....
# 901          https://www.ptt.cc/bbs/Gossiping/M.1574612200....
# 902          https://www.ptt.cc/bbs/Gossiping/M.1574612216....
# 903          https://www.ptt.cc/bbs/Gossiping/M.1574612283....
# 904          https://www.ptt.cc/bbs/Gossiping/M.1574612341....
# 905          https://www.ptt.cc/bbs/Gossiping/M.1574612352....
# 906          https://www.ptt.cc/bbs/Gossiping/M.1574612401....
# 907          https://www.ptt.cc/bbs/Gossiping/M.1574612440....
# 908          https://www.ptt.cc/bbs/Gossiping/M.1574612448....
# 909          https://www.ptt.cc/bbs/Gossiping/M.1574612494....
# 910          https://www.ptt.cc/bbs/Gossiping/M.1574611267....
# 911          https://www.ptt.cc/bbs/Gossiping/M.1574611271....
# 912          https://www.ptt.cc/bbs/Gossiping/M.1574611346....
# 913          https://www.ptt.cc/bbs/Gossiping/M.1574611482....
# 914          https://www.ptt.cc/bbs/Gossiping/M.1574611593....
# 915          https://www.ptt.cc/bbs/Gossiping/M.1574611599....
# 916          https://www.ptt.cc/bbs/Gossiping/M.1574611626....
# 917          https://www.ptt.cc/bbs/Gossiping/M.1574611627....
# 918          https://www.ptt.cc/bbs/Gossiping/M.1574611639....
#
# [918 rows x 5 columns]

# %% [markdown]
# # 無註解程式碼

# %%
import requests
import time
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np



def Gossiping_today_pop_articles(url):
    resp=requests.get(url,cookies={'over18': '1'})
    soup=BeautifulSoup(resp.text,'html5lib')
    
    paging_div = soup.find('div', 'btn-group btn-group-paging')
    PTT_URL = 'https://www.ptt.cc'        
    prev_url = PTT_URL+paging_div.find_all('a')[1]['href']
   

    articles = []
    divs = soup.find_all('div', 'r-ent')

    today = time.strftime("%m/%d").lstrip('0')

    
    for d in divs:
        if d.find('div', 'date').text.strip()==today:  
            push_count = 0
            push_str = d.find('div', 'nrec').text
            
            if push_str:
                try:
                    push_count = int(push_str) 
                except ValueError:
                    if push_str == '爆':
                        push_count = 99
                    elif push_str.startswith('X'):
                        push_count = -10

            if d.find('a'):
                title = d.find('a').text    
                date= d.find('div', 'date').text
                author = d.find('div', 'author').text 
                href = PTT_URL+d.find('a')['href']   
                articles.append({
                    'title':title,
                    'date':date,
                    'author':author,
                    'push_count':push_count,
                    'href':href})

    return articles,prev_url



def repeat_articles(url):
    articles=[]
    
    new_articles,prev_url=Gossiping_today_pop_articles(url)
    articles += new_articles
    new_articles, new_prev_url= Gossiping_today_pop_articles(prev_url)

    while new_articles!=[]:
        articles += new_articles
        new_articles,new_prev_url=Gossiping_today_pop_articles(new_prev_url)

    else:
        return articles

    
    
    
    
    
    
url='https://www.ptt.cc/bbs/Gossiping/index.html'    
articles=repeat_articles(url)

print('今天有', len(articles), '篇文章')
print('熱門文章(> 50 推):' )    
for a in articles:
    if int(a['push_count']) > 50:
        print(a)


        
        
data=repeat_articles(url)
name=['title','date','author','push_count','href']
test=pd.DataFrame(columns=name,data=data)
test.index = np.arange(1,len(test)+1)
test.index.names = ['article_NO.']


print(test)
test.to_csv('testcsv.csv',encoding='utf_8_sig')

# %% [markdown]
# # urllib套件版本的爬蟲

# %%
import urllib.request
import urllib.error
import time
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

#urllib.request.urlopen爬取大量資料容易WinError 10054,因此增加關閉resp與設置等待時間

def Gossiping_today_pop_articles(url):
    
    request = urllib.request.Request(url, headers={'User-Agent': 'Mozilla/5.0','cookie': 'over18=1'})
    try:
        resp = urllib.request.urlopen(url = request)
        soup=BeautifulSoup(resp.read(),'html5lib')
    
        paging_div = soup.find('div', 'btn-group btn-group-paging')
        PTT_URL = 'https://www.ptt.cc'        
        prev_url = PTT_URL+paging_div.find_all('a')[1]['href']
   

        articles = []
        divs = soup.find_all('div', 'r-ent')

        today = time.strftime("%m/%d").lstrip('0')

    
        for d in divs:
            if d.find('div', 'date').text.strip()==today:  
                push_count = 0
                push_str = d.find('div', 'nrec').text
            
                if push_str:
                    try:
                        push_count = int(push_str) 
                    except ValueError:
                        if push_str == '爆':
                            push_count = 99
                        elif push_str.startswith('X'):
                            push_count = -10

                if d.find('a'):
                    title = d.find('a').text    
                    date= d.find('div', 'date').text
                    author = d.find('div', 'author').text 
                    href = PTT_URL+d.find('a')['href']   
                    articles.append({
                    'title':title,
                    'date':date,
                    'author':author,
                    'push_count':push_count,
                    'href':href})

        resp.close()
        
    except urllib.error.URLError as e:
        print(e.reason)
        time.sleep(1)
        
    return articles,prev_url
        


def repeat_articles(url):
    articles=[]
    
    new_articles,prev_url=Gossiping_today_pop_articles(url)
    articles += new_articles
    new_articles, new_prev_url= Gossiping_today_pop_articles(prev_url)

    while new_articles!=[]:
        articles += new_articles
        new_articles,new_prev_url=Gossiping_today_pop_articles(new_prev_url)

    else:
        return articles

    
    
    
    
    
    
url='https://www.ptt.cc/bbs/Gossiping/index.html'    
articles=repeat_articles(url)

print('今天有', len(articles), '篇文章')
print('熱門文章(> 50 推):' )    
for a in articles:
    if int(a['push_count']) > 50:
        print(a)


        
        
data=repeat_articles(url)
name=['title','date','author','push_count','href']
test=pd.DataFrame(columns=name,data=data)
test.index = np.arange(1,len(test)+1)
test.index.names = ['article_NO.']


print(test)
test.to_csv('testcsv.csv',encoding='utf_8_sig')
