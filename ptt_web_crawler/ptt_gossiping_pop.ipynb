# %% [markdown]
# 從《Python 網路爬蟲與資料分析入門實戰》第三章的範例中練習爬蟲
#
# 此為第三章中批踢踢八卦版爬蟲範例中練習自寫程式碼
#
# 書中原始程式碼來源：https://github.com/jwlin/web-crawler-tutorial/tree/master/ch3

# %% [markdown]
# # 壹、寫爬蟲函數：(1)抓取今日的文章內容(2)重複抓取動作並儲存

# %%
import requests
import time
import json
from bs4 import BeautifulSoup

def Gossiping_today_pop_articles(url):
    #1.與網頁溝通/連線(使用requests套件)並帶入是否滿18歲的cookies
    resp=requests.get(url,cookies={'over18': '1'})
    
    #2.剖析網頁原始碼(使用BeautifulSoup剖析器)  
    soup=BeautifulSoup(resp.text,'html5lib')
    
    
    #3.取得該網頁的內容
        #3.1取得上一頁連結：(1)先定位上一頁連結的「大概位置」於標籤名稱div/屬性名稱btn-group btn-group-paging
    paging_div = soup.find('div', 'btn-group btn-group-paging')
        
                        ##(2)再定位「細部精確」的所在位置：找到所有a標籤中第2個a的href(網址)
    PTT_URL = 'https://www.ptt.cc'        
    prev_url = PTT_URL+paging_div.find_all('a')[1]['href']
        
        #3.2取得該網頁的文章內容：(1)設置儲存文章的變數
    articles = []
        
                            ##(2)定位文章內容的區塊：標籤名稱div/屬性名稱r-ent
    divs = soup.find_all('div', 'r-ent')
        
                            ##(3)創造一個今日的日期並符合PTT日期格式
    today = time.strftime("%m/%d").lstrip('0')

                            ##(4)使用for迴圈取得文章區塊內的所需內容
    for d in divs:
        
                            ##(5)先設置條件取得符合今日的文章：如果發文日期(位置：div標籤/date屬性)是今天
        if d.find('div', 'date').text.strip()==today:  
            
                            ##(6)取得推文數並編輯：(6.1)先設置一個為0的推文數
            push_count = 0
        
                                                ##(6.2)取得字串型態的原始推文數:位置div標籤名/nrec屬性
            push_str = d.find('div', 'nrec').text
            
                                                ##(6.3)如果原始推文存在,將字串轉為數字
            if push_str:
                try:
                    push_count = int(push_str) 
                
                                                ##如果轉換失敗表示原始推文數為文字或空白('爆'或 'X1','X2')
                                                ##空白的推文數保持為0
                except ValueError:
            
                                                ##(6.4)轉換失敗的「爆」文轉成99推文數
                    if push_str == '爆':
                        push_count = 99
                        
                                                ##(6.5)轉換失敗的「X」文轉成-10的推文數
                    elif push_str.startswith('X'):
                        push_count = -10
                        
                        
                            ##(7)取得文章連結/標題/作者並存至文章的變數中
                                    ##(7.1)如果文章存在：標籤a就是文章所在位置
            if d.find('a'):
                
                                    ##(7.2)取得文章標題：標籤a的字串
                title = d.find('a').text    
                
                                    ##(7.3)取得文章日期：div標籤/date屬性
                date= d.find('div', 'date').text
                
                                    ##(7.4)取得文章作者：標籤div屬性author的字串
                author = d.find('div', 'author').text 
                
                                    ##(7.5)取得文章網址：標籤a的href
                href = PTT_URL+d.find('a')['href']   
                
                                    ##(7.5)將上述變數儲存至文章的變數中
                articles.append({
                    'title':title,
                    'date':date,
                    'author':author,
                    'push_count':push_count,
                    'href':href})
                
                        ##(8)將程式結果返回文章內容
    return articles,prev_url


#4.取得該網頁的上一頁的文章內容(重複1.2.3的動作)
def repeat_articles(url):
    
    ##(4.1)創造放文章的變數
    articles=[]
    
    ##(4.2)利用自寫函數取得「原網頁文章內容」與「上一頁連結」
    new_articles,prev_url=Gossiping_today_pop_articles(url)
    
    ##(4.3)將原網頁內容放入變數中
    articles += new_articles
    
    ##(4.4)利用字寫函數取得的「上一頁連結」來取得「上一頁的文章內容與連結」
    new_articles, new_prev_url= Gossiping_today_pop_articles(prev_url)
    
    ##(4.5)如果「上一頁內容」不是空的=(文章日期為今日)
        ###因Gossiping_today_pop_articles函數中設定只抓取今日文章,若非今日變數則為[]
    while new_articles!=[]:
        
        ##(4.5.1)將「上一頁文章」放入變數中
        articles += new_articles
        
        ##(4.5.2)創造更新的「上一頁文章與連結」
        new_articles,new_prev_url=Gossiping_today_pop_articles(new_prev_url)
        
    ##(4.6)如果新的「上一頁內容」是空的=(文章日期非今日)則印出上述合併的所有文章內容
    else:
        return articles

# %% [markdown]
# # 貳、處理資料：(1)印出>50的今日文章 (2)所有今日文章存成csv檔案

# %%
#1.印出今日推文數>50的文章
    ##1.1將自寫函數設為文章變數
url='https://www.ptt.cc/bbs/Gossiping/index.html'
articles=repeat_articles(url)

    ##1.2印出總文章數
print('今天有', len(articles), '篇文章')

    ##1.3印出推文數>50的文章
print('熱門文章(> 50 推):' )    
for a in articles:
    if int(a['push_count']) > 50:
        print(a)
# Out:
# 今天有 929 篇文章
# 熱門文章(> 50 推):
# {'title': '[爆卦] 民進黨也提逕付二讀案啦！', 'date': '11/15', 'author': 'EvilisGood', 'push_count': 98, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573803527.A.22B.html'}
# {'title': '[新聞] 韓國瑜最沉重時曾同時背3間 每月房貸約24萬', 'date': '11/15', 'author': 'kid33', 'push_count': 55, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573803738.A.FA0.html'}
# {'title': 'Re: [爆卦] 今日被民進黨封殺之法案', 'date': '11/15', 'author': 'askaleroux', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573802102.A.A16.html'}
# {'title': '[新聞] 全台獨家！新竹推超狂「巨無霸桶裝珍奶」', 'date': '11/15', 'author': 'str8g', 'push_count': 66, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573802242.A.8F2.html'}
# {'title': '[新聞] 最狂庶民！不含海外資產\u3000韓國瑜六地炒', 'date': '11/15', 'author': 'a828203', 'push_count': 66, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573802339.A.BC8.html'}
# {'title': '[新聞] 不斷更新 國民黨不分區名單曝光 謝龍介越', 'date': '11/15', 'author': 'yor', 'push_count': 86, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573801004.A.0B7.html'}
# {'title': '[爆卦] 孫大千逐字稿', 'date': '11/15', 'author': 'Calderon', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573801176.A.D64.html'}
# {'title': 'Re: [爆卦] 今日被民進黨封殺之法案', 'date': '11/15', 'author': 'deann', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573800290.A.0D0.html'}
# {'title': '[爆卦] KMT黨部前的黨員訴求變成韓下吳上了', 'date': '11/15', 'author': 'Israfil', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573799477.A.792.html'}
# {'title': '[新聞] 開戰了!副主席郝龍斌要求 吳敦義退出不分區名單', 'date': '11/15', 'author': 'takuson', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573799605.A.D5E.html'}
# {'title': 'Re: [爆卦] 今日被民進黨封殺之法案', 'date': '11/15', 'author': 'eyck', 'push_count': 55, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573799811.A.991.html'}
# {'title': 'Re: [爆卦] 今日被民進黨封殺之法案', 'date': '11/15', 'author': 'seedli', 'push_count': 55, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573798131.A.D73.html'}
# {'title': 'Re: [爆卦] 今日被民進黨封殺之法案', 'date': '11/15', 'author': 'lastpost', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573794110.A.1C9.html'}
# {'title': '[新聞] 韓國瑜喊話公布房產獲利\u3000蔡辦附連結打', 'date': '11/15', 'author': 'xianfen', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573794343.A.EE1.html'}
# {'title': 'Re: [爆卦] 今日被民進黨封殺之法案', 'date': '11/15', 'author': 'TouchAgain', 'push_count': 79, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573794362.A.6BC.html'}
# {'title': '[爆卦] 胡金龍炸裂!', 'date': '11/15', 'author': 'thnlkj0665', 'push_count': 87, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573792383.A.CBA.html'}
# {'title': '[新聞] 中文大學升我國旗 香港網友：只要投錯一', 'date': '11/15', 'author': 'ishowhand', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573790487.A.B57.html'}
# {'title': '[爆卦] 今日被民進黨封殺之法案', 'date': '11/15', 'author': 'acln0816', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573790178.A.542.html'}
# {'title': '[問卦] 光頭葛格到底好在哪？', 'date': '11/15', 'author': 'frankcio2004', 'push_count': 61, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573789168.A.E53.html'}
# {'title': '[問卦] 相較小丑，葛格是不是彰顯出人性的光明', 'date': '11/15', 'author': 'wldon09', 'push_count': 55, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573787195.A.FEA.html'}
# {'title': '[新聞] 始終默默後援光頭哥哥！\u3000張家兄弟「低', 'date': '11/15', 'author': 'STAV72', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573787826.A.243.html'}
# {'title': '[爆卦] 礦業法遭國民兩黨聯手封殺', 'date': '11/15', 'author': 'abcdeffg', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573787854.A.460.html'}
# {'title': '[爆卦] 韓國瑜出售內湖工業宅創天價', 'date': '11/15', 'author': 'EDDIEHA', 'push_count': 77, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573788024.A.B8D.html'}
# {'title': 'Re: [新聞] 香港今公布Q3 GDP修正數據 將證實經濟衰', 'date': '11/15', 'author': 'allyourshit', 'push_count': 59, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573786959.A.CAE.html'}
# {'title': '[新聞] 中國海關總署：解除美國禽肉進口限制', 'date': '11/15', 'author': 'vodkalime607', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573786104.A.FB8.html'}
# {'title': '[新聞] 中國學生建立網路連儂牆支持香港中大', 'date': '11/15', 'author': 'aria0520', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573786218.A.306.html'}
# {'title': 'Re: [爆卦] 黃國昌夜宿立院搶排案 開直播嗆網軍', 'date': '11/15', 'author': 'deann', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573786353.A.CA6.html'}
# {'title': '[問卦] 張家兄弟是不是人真的很好？', 'date': '11/15', 'author': 'qazStarStar', 'push_count': 57, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573783895.A.C92.html'}
# {'title': '[新聞] 一張圖看韓國瑜房產買賣紀錄\u300036歲起「4', 'date': '11/15', 'author': 'Rambo', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573784917.A.6E9.html'}
# {'title': '[新聞] 小孩要上廁所!紅線臨停遭開單 男自認遭刁難與警大吵', 'date': '11/15', 'author': 'kenny1300175', 'push_count': 98, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573782696.A.C37.html'}
# {'title': '[新聞] 游錫堃：未料再度紅塵 邁向正常國家責無', 'date': '11/15', 'author': 'br06', 'push_count': 89, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573782157.A.0CF.html'}
# {'title': 'Re: [爆卦] LIVE 韓氏夫婦房產一次公開！', 'date': '11/15', 'author': 'sean0912', 'push_count': 59, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573782630.A.641.html'}
# {'title': '[問卦] 卡提諾狂新聞是不是沒落了?', 'date': '11/15', 'author': 'ivorysoap', 'push_count': 74, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573780538.A.2C1.html'}
# {'title': '[新聞] 香港今公布Q3 GDP修正數據 將證實經濟衰', 'date': '11/15', 'author': 'CavendishJr', 'push_count': 54, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573780602.A.F4E.html'}
# {'title': 'Re: [新聞] 民進黨中執會通過不分區立委完整名單', 'date': '11/15', 'author': 'deann', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573781565.A.470.html'}
# {'title': '[爆卦] LIVE 韓氏夫婦房產一次公開！', 'date': '11/15', 'author': 'kenbo', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573781755.A.F43.html'}
# {'title': 'Re: [爆卦] 黃國昌夜宿立院搶排案 開直播嗆網軍', 'date': '11/15', 'author': 'TTDEarl', 'push_count': 73, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573779474.A.A09.html'}
# {'title': 'Re: [問卦] 把螢幕的RGB的B調0，對眼睛最好？= =', 'date': '11/15', 'author': 'abcde010710', 'push_count': 70, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573779989.A.ED0.html'}
# {'title': '[問卦] 大紀元什麼時候可信了?', 'date': '11/15', 'author': 'rioku', 'push_count': 98, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573776993.A.10A.html'}
# {'title': '[問卦] 好奇大家希望麥當勞重賣哪個產品', 'date': '11/15', 'author': 'QQOQQO', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573777917.A.275.html'}
# {'title': 'Re: [爆卦] 黃國昌夜宿立院搶排案 開直播嗆網軍', 'date': '11/15', 'author': 'ueewen', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573776645.A.CE3.html'}
# {'title': '[新聞] 港警威脅19歲女生：信不信我在這強姦你？', 'date': '11/15', 'author': 'pulagu', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573772805.A.CB6.html'}
# {'title': 'Re: [問卦] 很想知道張家幫了光頭哥哥什麼', 'date': '11/15', 'author': 'Mashin5566', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573763482.A.8E2.html'}
# {'title': '《香港人權及民主法案》美國參議院啟動「熱線」', 'date': '11/15', 'author': 'lifelikeplay', 'push_count': 51, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573768030.A.7D2.html'}
# {'title': '[問卦] 光頭哥哥陪伴了你哪一段時光', 'date': '11/15', 'author': 'DevilHotel', 'push_count': 51, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573752195.A.1C6.html'}
# {'title': '[問卦] 如果統神一樣出現的情況 大家會哀悼嗎？', 'date': '11/15', 'author': 'ruby00514', 'push_count': 66, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573750781.A.C71.html'}
# {'title': '[爆卦] 黃國昌夜宿立院搶排案 開直播嗆網軍', 'date': '11/15', 'author': 'jx2tw', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573750803.A.83A.html'}
# {'title': '[問卦] 上帝是不是帶錯光頭了？', 'date': '11/15', 'author': 'ptt80357', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573749043.A.003.html'}
# {'title': '[問卦] 年代陳凝觀今天火氣特別大', 'date': '11/15', 'author': 'ken841520', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573748231.A.9A5.html'}
# {'title': '[問卦] 中共對人類有益的發明是啥啊？', 'date': '11/15', 'author': 'linaomasa', 'push_count': 53, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573748618.A.EF2.html'}
# {'title': '[新聞] 中國宣布 解除美國家禽進口禁令  ', 'date': '11/15', 'author': 'qazsedcft', 'push_count': 57, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573747320.A.359.html'}

# %%
import pandas as pd
import numpy as np

#2.儲存所有今日文章
    ##2.1將爬下來的文章設為字典(dict)
dict=repeat_articles(url)

    ##2.2將字典轉成DataFrame型式(columns可不寫入，資料中列的名稱會照字母排序)
name=['title','date','author','push_count','href']
test=pd.DataFrame(columns=name,data=dict)

    ##2.3把索引改成從1開始
test.index = np.arange(1,len(test)+1)
    
    ##2.4將索引名稱改為編號
test.index.names = ['article_NO.']

    ##印出結果並儲存成CSV檔案
print(test)
test.to_csv('testcsv.csv',encoding='utf_8_sig')
# Out:
#                                     title   date        author  push_count  \
# article_NO.
# 1                       [問卦] 智力測驗後發現自己是智障  11/15      hiimlove           4
# 2                    Re: [爆卦] 今日被民進黨封殺之法案  11/15        takase           0
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np



def Gossiping_today_pop_articles(url):
    resp=requests.get(url,cookies={'over18': '1'})
    soup=BeautifulSoup(resp.text,'html5lib')
    
    paging_div = soup.find('div', 'btn-group btn-group-paging')
    PTT_URL = 'https://www.ptt.cc'        
    prev_url = PTT_URL+paging_div.find_all('a')[1]['href']
   

    articles = []
    divs = soup.find_all('div', 'r-ent')

    today = time.strftime("%m/%d").lstrip('0')

    
    for d in divs:
        if d.find('div', 'date').text.strip()==today:  
            push_count = 0
            push_str = d.find('div', 'nrec').text
            
            if push_str:
                try:
                    push_count = int(push_str) 
                except ValueError:
                    if push_str == '爆':
                        push_count = 99
                    elif push_str.startswith('X'):
                        push_count = -10

            if d.find('a'):
                title = d.find('a').text    
                date= d.find('div', 'date').text
                author = d.find('div', 'author').text 
                href = PTT_URL+d.find('a')['href']   
                articles.append({
                    'title':title,
                    'date':date,
                    'author':author,
                    'push_count':push_count,
                    'href':href})

    return articles,prev_url



def repeat_articles(url):
    articles=[]
    
    new_articles,prev_url=Gossiping_today_pop_articles(url)
    articles += new_articles
    new_articles, new_prev_url= Gossiping_today_pop_articles(prev_url)

    while new_articles!=[]:
        articles += new_articles
        new_articles,new_prev_url=Gossiping_today_pop_articles(new_prev_url)

    else:
        return articles

    
    
    
    
    
    
url='https://www.ptt.cc/bbs/Gossiping/index.html'    
articles=repeat_articles(url)

print('今天有', len(articles), '篇文章')
print('熱門文章(> 50 推):' )    
for a in articles:
    if int(a['push_count']) > 50:
        print(a)


        
        
dict=repeat_articles(url)
name=['title','date','author','push_count','href']
test=pd.DataFrame(columns=name,data=dict)
test.index = np.arange(1,len(test)+1)
test.index.names = ['article_NO.']


print(test)
test.to_csv('testcsv.csv',encoding='utf_8_sig')
# Out:
# 今天有 931 篇文章
# 熱門文章(> 50 推):
# {'title': '[爆卦] 民進黨也提逕付二讀案啦！', 'date': '11/15', 'author': 'EvilisGood', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573803527.A.22B.html'}
# {'title': '[新聞] 韓國瑜最沉重時曾同時背3間 每月房貸約24萬', 'date': '11/15', 'author': 'kid33', 'push_count': 55, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573803738.A.FA0.html'}
# {'title': 'Re: [爆卦] 今日被民進黨封殺之法案', 'date': '11/15', 'author': 'askaleroux', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573802102.A.A16.html'}
# {'title': '[新聞] 全台獨家！新竹推超狂「巨無霸桶裝珍奶」', 'date': '11/15', 'author': 'str8g', 'push_count': 67, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573802242.A.8F2.html'}
# {'title': '[新聞] 最狂庶民！不含海外資產\u3000韓國瑜六地炒', 'date': '11/15', 'author': 'a828203', 'push_count': 66, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573802339.A.BC8.html'}
# {'title': '[新聞] 不斷更新 國民黨不分區名單曝光 謝龍介越', 'date': '11/15', 'author': 'yor', 'push_count': 86, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573801004.A.0B7.html'}
# {'title': '[爆卦] 孫大千逐字稿', 'date': '11/15', 'author': 'Calderon', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573801176.A.D64.html'}
# {'title': '[新聞] 國民黨不分區立委提名恐生變 吳斯懷：不', 'date': '11/15', 'author': 'ccf52881', 'push_count': 51, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573801467.A.FBE.html'}
# {'title': 'Re: [爆卦] 今日被民進黨封殺之法案', 'date': '11/15', 'author': 'deann', 'push_count': 97, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573800290.A.0D0.html'}
# {'title': '[爆卦] KMT黨部前的黨員訴求變成韓下吳上了', 'date': '11/15', 'author': 'Israfil', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573799477.A.792.html'}
# {'title': '[新聞] 開戰了!副主席郝龍斌要求 吳敦義退出不分區名單', 'date': '11/15', 'author': 'takuson', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573799605.A.D5E.html'}
# {'title': 'Re: [爆卦] 今日被民進黨封殺之法案', 'date': '11/15', 'author': 'eyck', 'push_count': 55, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573799811.A.991.html'}
# {'title': 'Re: [爆卦] 今日被民進黨封殺之法案', 'date': '11/15', 'author': 'seedli', 'push_count': 55, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573798131.A.D73.html'}
# {'title': 'Re: [爆卦] 今日被民進黨封殺之法案', 'date': '11/15', 'author': 'lastpost', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573794110.A.1C9.html'}
# {'title': '[新聞] 韓國瑜喊話公布房產獲利\u3000蔡辦附連結打', 'date': '11/15', 'author': 'xianfen', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573794343.A.EE1.html'}
# {'title': 'Re: [爆卦] 今日被民進黨封殺之法案', 'date': '11/15', 'author': 'TouchAgain', 'push_count': 79, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573794362.A.6BC.html'}
# {'title': '[爆卦] 胡金龍炸裂!', 'date': '11/15', 'author': 'thnlkj0665', 'push_count': 87, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573792383.A.CBA.html'}
# {'title': '[新聞] 中文大學升我國旗 香港網友：只要投錯一', 'date': '11/15', 'author': 'ishowhand', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573790487.A.B57.html'}
# {'title': '[爆卦] 今日被民進黨封殺之法案', 'date': '11/15', 'author': 'acln0816', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573790178.A.542.html'}
# {'title': '[問卦] 光頭葛格到底好在哪？', 'date': '11/15', 'author': 'frankcio2004', 'push_count': 61, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573789168.A.E53.html'}
# {'title': '[問卦] 相較小丑，葛格是不是彰顯出人性的光明', 'date': '11/15', 'author': 'wldon09', 'push_count': 55, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573787195.A.FEA.html'}
# {'title': '[新聞] 始終默默後援光頭哥哥！\u3000張家兄弟「低', 'date': '11/15', 'author': 'STAV72', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573787826.A.243.html'}
# {'title': '[爆卦] 礦業法遭國民兩黨聯手封殺', 'date': '11/15', 'author': 'abcdeffg', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573787854.A.460.html'}
# {'title': '[爆卦] 韓國瑜出售內湖工業宅創天價', 'date': '11/15', 'author': 'EDDIEHA', 'push_count': 77, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573788024.A.B8D.html'}
# {'title': 'Re: [新聞] 香港今公布Q3 GDP修正數據 將證實經濟衰', 'date': '11/15', 'author': 'allyourshit', 'push_count': 59, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573786959.A.CAE.html'}
# {'title': '[新聞] 中國海關總署：解除美國禽肉進口限制', 'date': '11/15', 'author': 'vodkalime607', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573786104.A.FB8.html'}
# {'title': '[新聞] 中國學生建立網路連儂牆支持香港中大', 'date': '11/15', 'author': 'aria0520', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573786218.A.306.html'}
# {'title': 'Re: [爆卦] 黃國昌夜宿立院搶排案 開直播嗆網軍', 'date': '11/15', 'author': 'deann', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573786353.A.CA6.html'}
# {'title': '[問卦] 張家兄弟是不是人真的很好？', 'date': '11/15', 'author': 'qazStarStar', 'push_count': 57, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573783895.A.C92.html'}
# {'title': '[新聞] 一張圖看韓國瑜房產買賣紀錄\u300036歲起「4', 'date': '11/15', 'author': 'Rambo', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573784917.A.6E9.html'}
# {'title': '[新聞] 小孩要上廁所!紅線臨停遭開單 男自認遭刁難與警大吵', 'date': '11/15', 'author': 'kenny1300175', 'push_count': 98, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573782696.A.C37.html'}
# {'title': '[新聞] 游錫堃：未料再度紅塵 邁向正常國家責無', 'date': '11/15', 'author': 'br06', 'push_count': 89, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573782157.A.0CF.html'}
# {'title': 'Re: [爆卦] LIVE 韓氏夫婦房產一次公開！', 'date': '11/15', 'author': 'sean0912', 'push_count': 59, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573782630.A.641.html'}
# {'title': '[問卦] 卡提諾狂新聞是不是沒落了?', 'date': '11/15', 'author': 'ivorysoap', 'push_count': 74, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573780538.A.2C1.html'}
# {'title': '[新聞] 香港今公布Q3 GDP修正數據 將證實經濟衰', 'date': '11/15', 'author': 'CavendishJr', 'push_count': 54, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573780602.A.F4E.html'}
# {'title': 'Re: [新聞] 民進黨中執會通過不分區立委完整名單', 'date': '11/15', 'author': 'deann', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573781565.A.470.html'}
# {'title': '[爆卦] LIVE 韓氏夫婦房產一次公開！', 'date': '11/15', 'author': 'kenbo', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573781755.A.F43.html'}
# {'title': 'Re: [爆卦] 黃國昌夜宿立院搶排案 開直播嗆網軍', 'date': '11/15', 'author': 'TTDEarl', 'push_count': 73, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573779474.A.A09.html'}
# {'title': 'Re: [問卦] 把螢幕的RGB的B調0，對眼睛最好？= =', 'date': '11/15', 'author': 'abcde010710', 'push_count': 71, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573779989.A.ED0.html'}
# {'title': '[問卦] 大紀元什麼時候可信了?', 'date': '11/15', 'author': 'rioku', 'push_count': 98, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573776993.A.10A.html'}
# {'title': '[問卦] 好奇大家希望麥當勞重賣哪個產品', 'date': '11/15', 'author': 'QQOQQO', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573777917.A.275.html'}
# {'title': 'Re: [爆卦] 黃國昌夜宿立院搶排案 開直播嗆網軍', 'date': '11/15', 'author': 'ueewen', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573776645.A.CE3.html'}
# {'title': '[新聞] 港警威脅19歲女生：信不信我在這強姦你？', 'date': '11/15', 'author': 'pulagu', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573772805.A.CB6.html'}
# {'title': 'Re: [問卦] 很想知道張家幫了光頭哥哥什麼', 'date': '11/15', 'author': 'Mashin5566', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573763482.A.8E2.html'}
# {'title': '《香港人權及民主法案》美國參議院啟動「熱線」', 'date': '11/15', 'author': 'lifelikeplay', 'push_count': 51, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573768030.A.7D2.html'}
# {'title': '[問卦] 光頭哥哥陪伴了你哪一段時光', 'date': '11/15', 'author': 'DevilHotel', 'push_count': 51, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573752195.A.1C6.html'}
# {'title': '[問卦] 如果統神一樣出現的情況 大家會哀悼嗎？', 'date': '11/15', 'author': 'ruby00514', 'push_count': 66, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573750781.A.C71.html'}
# {'title': '[爆卦] 黃國昌夜宿立院搶排案 開直播嗆網軍', 'date': '11/15', 'author': 'jx2tw', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573750803.A.83A.html'}
# {'title': '[問卦] 上帝是不是帶錯光頭了？', 'date': '11/15', 'author': 'ptt80357', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573749043.A.003.html'}
# {'title': '[問卦] 年代陳凝觀今天火氣特別大', 'date': '11/15', 'author': 'ken841520', 'push_count': 99, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573748231.A.9A5.html'}
# {'title': '[問卦] 中共對人類有益的發明是啥啊？', 'date': '11/15', 'author': 'linaomasa', 'push_count': 53, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.1573748618.A.EF2.html'}
# {'title': '[新聞] 中國宣布 解除美國家禽進口禁令  ', 'date': '11/15', 'author': 'qazsedcft', 'push_count': 57, 'href': 'https://www.ptt.cc/bbs/Gossiping/M.
# 908               [問卦] 到底是多強的精神力或心態可以變成那樣  11/15     sam930114          13
# 909             Re: [問卦] 光頭哥哥走了...好想哭怎麼辦？  11/15      hiimlive           7
# 910          Re: [新聞] 被誤認大陸人！日男出差香港「示威者壓地  11/15      yoyoflag           0
# 911                    [問卦] 有八卦板/搜不到的字ㄇ？   11/15   chi12345678           3
# 912             Re: [新聞] 台灣高麗菜外銷加拿大 今裝櫃啟航  11/15     skyprayer           4
# 913                         [問卦] 你不是真正的快樂  11/15        wang1b           5
# 914                   [問卦] 登錄次數1000了該怎麼慶祝  11/15     Tohkachan           0
# 915                          [問卦] 鄉民很偽善的卦  11/15  bubblebeauty         -10
# 916                      [問卦] 為啥台灣沒拋棄式手機？  11/15    Superxixai           5
# 917                  [問卦] 光頭哥哥上次的直播就間接透露了  11/15        cokepd          27
# 918          Re: [新聞] 頭破血流！誤認是陸客 日男慘遭港抗議群  11/15          Asce           0
# 919                    [問卦] 天堂也有胖老爹嗎чQдQг  11/15      sven1130           6
# 920                    [問卦] 光頭哥哥確實留下東西了……  11/15       acz0221          19
# 921                        [問卦] 最好的報仇的八卦？  11/15      a9591308           2
# 922                [新聞] 中國宣布 解除美國家禽進口禁令    11/15     qazsedcft          57
# 923                 Re: [問卦] 十年後中國大陸會多強的卦  11/15  WalterbyJeff           3
# 924                     [問卦] 你的轉角小麵店對我打了烊  11/15    Metallicat          10
# 925              [爆卦] 黃國昌呼籲時力推人選擊敗屏東周典論家族  11/15         WuSam          28
# 926                   [問卦] 有沒有心情很沉重睡不著的八卦  11/15       ray0215          14
# 927                      [問卦] 健身環到底有什麼好玩?  11/15         ideos           0
# 928             [爆卦] 快訊/網紅光頭哥哥驚傳病逝 網友一遍哀悼  11/15   superme0678          21
# 929                [問卦] 好人不長命，禍害遺千年是不是真的?  11/15     Beanoodle           4
# 930                  Re: [問卦] 老天是不是帶錯光頭走了  11/15       ewqazxs           0
# 931                        [問卦] 台科大怎麼沒跟上？  11/15      plusseal           0
#
#                                                           href
# article_NO.
# 1            https://www.ptt.cc/bbs/Gossiping/M.1573804757....
# 2            https://www.ptt.cc/bbs/Gossiping/M.1573804787....
# 3            https://www.ptt.cc/bbs/Gossiping/M.1573804876....
# 4            https://www.ptt.cc/bbs/Gossiping/M.1573804947....
# 5            https://www.ptt.cc/bbs/Gossiping/M.1573805023....
# 6            https://www.ptt.cc/bbs/Gossiping/M.1573805062....
# 7            https://www.ptt.cc/bbs/Gossiping/M.1573805133....
# 8            https://www.ptt.cc/bbs/Gossiping/M.1573805163....
# 9            https://www.ptt.cc/bbs/Gossiping/M.1573805167....
# 10           https://www.ptt.cc/bbs/Gossiping/M.1573805253....
# 11           https://www.ptt.cc/bbs/Gossiping/M.1573805271....
# 12           https://www.ptt.cc/bbs/Gossiping/M.1573805273....
# 13           https://www.ptt.cc/bbs/Gossiping/M.1573805282....
# 14           https://www.ptt.cc/bbs/Gossiping/M.1573805289....
# 15           https://www.ptt.cc/bbs/Gossiping/M.1573805368....
