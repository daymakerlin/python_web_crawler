# %% [markdown]
# 從《Python 網路爬蟲與資料分析入門實戰》第三章的範例中練習爬蟲
#
# 從第三章Dcard熱門文章爬蟲範例中練習自己寫的程式碼
#
# 書中原始程式碼來源：https://github.com/jwlin/web-crawler-tutorial/tree/master/ch3

# %% [markdown]
# # 熱門文章：(1)爬取資料 (2)儲存資料

# %%
import requests
import re
from bs4 import BeautifulSoup


url = 'https://www.dcard.tw/f'
#1.向網站發出請求
resp = requests.get(url)
#2.剖析網頁原始碼
soup = BeautifulSoup(resp.text, 'html.parser')
#3.定位資訊大概位置
dcard= soup.find_all('div', re.compile('NormalPostLayout__Left.+'))
#4.創建空的清單存放資訊
articles = []


#5.用迴圈將資料一行一行爬取
for d in dcard:
    #5.1創建一個空的字典(放資料)
    new=dict()
    #5.2創建「標題」:定位h3標籤的字串(去掉空格)
    new['title'] = d.h3.text.strip()
    #5.3創建「摘要」:定位所有第二個div標籤的字串
    new['summary'] = d.find_all('div')[1].text.strip()
    #5.4創建「愛心數」:找「在第三個div標籤的字串中的第二個物件」符合一或多個數字條件的
        ##正則表達式:\d+代表一或多個數字
    new['mark'] = re.findall("\d+",d.find_all('div')[2].text.strip())[1]
    #5.5創建「回應數」:找「在第三個div標籤的字串中的第一個物件」符合一或多個數字條件的
    new['response'] = re.findall("\d+",d.find_all('div')[2].text.strip())[0]
    #5.6創建「網址」:在dcard位置的父節點的父節點的父節點的網址
    new['href'] = 'https://www.dcard.tw' + d.parent.parent.parent['href']
    #5.7將資料加進原先的清單中
    articles.append(new)

    #5.8印出資料筆數
print('共 %d 篇' % (len(articles)))
    #5.9印出前三筆資料查看
for a in articles[:3]:
    print(a)
# Out:
# 共 31 篇
# {'title': '小笨狗，你害我好丟臉！', 'summary': '這是我們家的小蠢狗，他叫阿蠢。它是一隻吉娃娃，相較你看過的其他吉娃娃還算可愛，但還是很機掰。今天，來說說一個神奇的故事。是一個關於我、我們家的小蠢狗，還有關於我男朋友的故事。那是一個，完全沒有一點風又', 'mark': '178', 'response': '10597', 'href': 'https://www.dcard.tw/f/relationship/p/232603620-小笨狗，你害我好丟臉！'}
# {'title': '終於成功讓韓粉老爸動搖了', 'summary': '聽這集廣播聽到毛骨悚然，滿滿既視感啊！！！，來賓的爸爸根本跟我爸870%像啊，1.父權，經不起質疑，只要一有人challenge他，就會嚷嚷自己是一家之主️，2.愛自稱中立李姓選民，口頭禪是「誰當選有', 'mark': '427', 'response': '6836', 'href': 'https://www.dcard.tw/f/trending/p/232604659-終於成功讓韓粉老爸動搖了'}
# {'title': '捷運站的清潔人員哭了', 'summary': '今天要搭捷運回家的時候走在電扶梯上，剛好清潔人員正在擦電扶梯的扶手，所以她到電扶梯的底的時候停留了一下。正常人看到應該都會從她左側繞過去，也不會說什麼，畢竟他正在工作中。沒想到我前面的一個阿嬤直接用力', 'mark': '108', 'response': '5571', 'href': 'https://www.dcard.tw/f/mood/p/232607780-捷運站的清潔人員哭了'}

# %%
import pandas as pd
import numpy as np

#6.處理資料並儲存
    #6.1創建欄位
name=['title','summary','mark','response','href']
    #6.2將資料轉成DataFrame(輸入欄位與資料)
test=pd.DataFrame(columns=name,data=articles)
    #6.3將索引從1開始(預設從0)
test.index = np.arange(1,len(test)+1)
    #6.4重新命名所引為文章編號
test.index.names = ['article_NO.']

    #6.5印出結果
print(test)
    #6.6儲存成csv檔
test.to_csv('dcardcsv.csv',encoding='utf_8_sig')
# Out:
#                                                          title  \
# article_NO.
# 1                                                  小笨狗，你害我好丟臉！
# 2                                                 終於成功讓韓粉老爸動搖了
# 3                                                   捷運站的清潔人員哭了
# 4                                                    好像買太小了...
# 5            💋卡友勸敗美到心花開！品木宣言🌹心花綻放精油唇膏💄 聖誕節🎄買二送一😍試色就抽「包色」24支...
# 6                                                        和男友換臉
# 7                                                    那年，是2013年
# 8                                               我爸撿到槍 把韓國瑜當形容詞
# 9                                                 給他們一個機會—喜憨兒🍲
# 10                                                      幫JYPQQ
# 11                                                    4個月減17公斤
# 12                                            真的有把我噁心到！浙江衛視沒有心
# 13                                                    軍校舞會穿搭分享
# 14                                                   妳看起來很年輕..
# 15                                              #食譜 蛤蜊蓋飯（好好吃😋）
# 16                                                         妝太濃
# 17                                              原來Dcard情節都是別人的
# 18                                             台南人請大家幫忙找找失蹤的親人
# 19                                                      不理性搭電梯
# 20                                                 尷尬的愛愛 (微西斯)
# 21                                                   梗圖事件在日常上演
# 22                                              韓國瑜的快樂砂石場 簡易介紹
# 23                                                         地理課
# 24                                                     一心求死的男人
# 25                                              台南人的早餐不是只有牛肉湯！
# 26                                                   我養的是工讀生？🤔
# 27                                                 #分享 各種隱眼的實戴
# 28                                             不是UAENA的IU演唱會心得
# 29                                                李宰旭出道一週年快樂❤️
# 30                               💜BTS防彈少年團💜2019 MMA 舞台 #解析 #安利
# 31                                         都是橋本環奈讓我大敗家之SUGAO開箱
#
#                                                        summary  mark response  \
# article_NO.
# 1            這是我們家的小蠢狗，他叫阿蠢。它是一隻吉娃娃，相較你看過的其他吉娃娃還算可愛，但還是很機掰。...   178    10597
# 2            聽這集廣播聽到毛骨悚然，滿滿既視感啊！！！，來賓的爸爸根本跟我爸870%像啊，1.父權，經不...   427     6836
# 3            今天要搭捷運回家的時候走在電扶梯上，剛好清潔人員正在擦電扶梯的扶手，所以她到電扶梯的底的時候...   108     5571
# 4            我女友去寵物展幫我買了一個貓咪玩具給斑斑，他說這個五公斤適用，於是今天我拿給了斑斑，他在試尺...    50     5164
# 5            去年被美妝Youtuber推爆的品木宣言心花綻放精油唇膏和大家一起美美的過冬天了！！！，超多...  2038      570
# 6            我跟男友都會看漫畫女神降臨，最近有一集朱靜跟書竣他們一起玩了換臉，男友昨天就說我們也來玩換臉...    62     4640
# 7            前幾天，YouTube神奇的演算法帶我回到了這個影片，-，2013年，可以說是我最想回去的一...    92     3592
# 8            今天我爸陪我去某家衣服店換貨，他在店外面等，排隊時 在我前面的是一個有點年紀的女生，她因為人...    52     3458
# 9            大家好～今天我想分享在台北的餐廳，巷弄中的火鍋店不是很引入注目，但是裡面的店員卻有著讓人開心...    28     3065
# 10           昨天晚上打開ig看到這個，嚇了一下，想說是被盜了嗎，結果宣美一分鐘內被退了100多個追蹤者，...    60     3008
# 11                                                    胖女孩瘦身後穿搭    98     2886
# 12           什麼樣的公司就有什麼樣的人！，說了這麼令人作嘔的話 還像個人嗎？真正令高以翔致死的絕對是那黃...    55     2144
# 13           又到了12月各種舞會的季節，自從三年前第一次準備參加舞會就會開始爬各種舞會文，分享的也好穿搭...    50     2083
# 14           昨天跟朋友逛街，遇到造勢場合，雖然明年的我還沒有投票權ಠ_ಠ，還是好奇的去看看，突然有兩個人...    15     1661
# 15           嗨嗨～我又要來分享手作了，這次來分享蛤蜊蓋飯的食譜，在美食板的限時動態發了一張蛤蜊蓋飯照片想...    28     1531
# 16           每到假日就是可以好好睡飽，起床有充足的時間可以研究美妝版大神的眼影畫法，對我來說我覺得化妝是...   192     1344
# 17           來陪考的我根本沒想到找人合買星巴克買一送一的Dcard情節也會讓我遇到，依照Dcard走向，...    25     1333
# 18           ［協尋］，請各位幫忙找照片上的老年男子，名叫楊金隆，年約90歲，有輕度矢智。於今日12/1中...     8     1309
# 19           我搭電梯要上21樓，中途到7樓有個阿桑進來，我跟她說 是上樓哦，她沒理我 就直接進來，關門過...    23     1292
# 20           男友告訴過我他看片喜歡看強暴那些，但我個人是喜歡女生也享受的畫面，特別是女生主動那些，因為覺...    49     1151
# 21           上上禮拜天也就是1117，是小弟的生日，我大學4年兄弟，突然賴我要我去我家附近的超商取貨，說...    42     1116
# 22           簡單介紹，1.李佳芬家族採砂石，2.立委韓國瑜去關說，3.蓋新堤防圍起來挖，4.農用地變礦業...   101     1099
# 23           有一天上地理課，老師問著，老師：對於日本的礦產部分，日本的原油稀少，鐵礦稀少，還有呢？小明：...    12     1027
# 24           今天中午和朋友一起去吃飯，去吃的那間店外面的座位可以抽菸，所以我們就坐在外面吃，吃到一半 有...    12      913
# 25           身為一個台南人，我還真沒排過六千牛肉湯，不過台南的早餐那麼多，真是不懂為啥大家都要排六千ㄋ🧐...    43      883
# 26           整理我家帥橘的照片，然後翻到以前還不到一歲的照片，有一天抱他起來自拍，結果拍完才發現他的表情...    29      866
# 27           從以前就習慣把自己戴過的隱眼拍照紀錄下來，然後再和自己覺得有fu的圖組起來，以下的照片也可以...    24      803
# 28           在11/29號這天，一整個星期都在聽Blueming的我發誓，一定要去一次IU的演唱會，因為...    60      754
# 29           在最一開始就先放我最愛的照片️，從WWW才開始關注他的到後來偶然直接愛上，只有21歲出道經驗...    16      718
# 30           今年的MMA表演一樣很精彩，舞台官方完整版，大黑這次竟然有上傳官方版的 真難得，MMA表演的...    73      695
# 31           晃個屈臣氏被橋本環奈煞到！跟貓一樣萌，看著看著怎麼已經放到籃子了找她代言根本超可以！，組合裡...    32      690
#
#                                                           href
# article_NO.
# 1            https://www.dcard.tw/f/relationship/p/23260362...
# 2            https://www.dcard.tw/f/trending/p/232604659-終於...
# 3            https://www.dcard.tw/f/mood/p/232607780-捷運站的清潔...
# 4             https://www.dcard.tw/f/pet/p/232605062-好像買太小了...
# 5            https://www.dcard.tw/f/makeup/p/232566996-💋卡友勸...
# 6               https://www.dcard.tw/f/funny/p/232603506-和男友換臉
# 7            https://www.dcard.tw/f/entertainer/p/232606960...
# 8            https://www.dcard.tw/f/funny/p/232604877-我爸撿到槍...
# 9            https://www.dcard.tw/f/food/p/232605921-給他們一個機...
# 10           https://www.dcard.tw/f/entertainer/p/232606427...
# 11           https://www.dcard.tw/f/weight_loss/p/232605341...
# 12           https://www.dcard.tw/f/entertainer/p/232607735...
# 13           https://www.dcard.tw/f/dressup/p/232603852-軍校舞...
# 14           https://www.dcard.tw/f/funny/p/232603527-妳看起來很...
# 15           https://www.dcard.tw/f/food/p/232606919-＃食譜-蛤蜊...
# 16                 https://www.dcard.tw/f/girl/p/232606191-妝太濃
# 17           https://www.dcard.tw/f/mood/p/232603842-原來Dcar...
# 18           https://www.dcard.tw/f/mood/p/232605810-台南人請大家...
# 19             https://www.dcard.tw/f/funny/p/232605173-不理性搭電梯
# 20           https://www.dcard.tw/f/relationship/p/23260576...
# 21           https://www.dcard.tw/f/mood/p/232605562-梗圖事件在日常上演
# 22           https://www.dcard.tw/f/trending/p/232603791-韓國...
# 23                 https://www.dcard.tw/f/joke/p/232605310-地理課
# 24            https://www.dcard.tw/f/funny/p/232606673-一心求死的男人
# 25           https://www.dcard.tw/f/food/p/232604422-台南人的早餐...
# 26            https://www.dcard.tw/f/pet/p/232603660-我養的是工讀生？🤔
# 27           https://www.dcard.tw/f/contact_lens/p/23260559...
# 28           https://www.dcard.tw/f/entertainer/p/232605541...
# 29           https://www.dcard.tw/f/entertainer/p/232607324...
# 30           https://www.dcard.tw/f/entertainer/p/232607438...
# 31           https://www.dcard.tw/f/makeup/p/232605568-都是橋本...

# %% [markdown]
# # 無註解程式碼

# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np


url = 'https://www.dcard.tw/f'

resp = requests.get(url)
soup = BeautifulSoup(resp.text, 'html.parser')
dcard= soup.find_all('div', re.compile('NormalPostLayout__Left.+'))
articles = []

for d in dcard:
    new=dict()
    new['title'] = d.h3.text.strip()
    new['summary'] = d.find_all('div')[1].text.strip()
    new['mark'] = re.findall("\d+",d.find_all('div')[2].text.strip())[1]
    new['response'] = re.findall(r"\d+",d.find_all('div')[2].text.strip())[0]
    new['href'] = 'https://www.dcard.tw' + d.parent.parent.parent['href']
    articles.append(new)
    
print('共 %d 篇' % (len(articles)))
for a in articles[:3]:
    print(a)

    
name=['title','summary','mark','response','href']
test=pd.DataFrame(columns=name,data=articles)
test.index = np.arange(1,len(test)+1)
test.index.names = ['article_NO.']
print(test)

test.to_csv('dcardcsv.csv',encoding='utf_8_sig')

# %% [markdown]
# # urllib套件版本的爬蟲

# %%
import urllib.request
import re
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np


url = 'https://www.dcard.tw/f'

#urllib直接抓資料容易WinError 10054,因此輸入User-Agent
request = urllib.request.Request(url, headers={'User-Agent': 'Mozilla/5.0'})
resp = urllib.request.urlopen(url = request)
soup = BeautifulSoup(resp, 'html.parser')
dcard= soup.find_all('div', re.compile('NormalPostLayout__Left.+'))
articles = []

for d in dcard:
    new=dict()
    new['title'] = d.h3.text.strip()
    new['summary'] = d.find_all('div')[1].text.strip()
    new['mark'] = re.findall("\d+",d.find_all('div')[2].text.strip())[1]
    new['response'] = re.findall(r"\d+",d.find_all('div')[2].text.strip())[0]
    new['href'] = 'https://www.dcard.tw' + d.parent.parent.parent['href']
    articles.append(new)
    
print('共 %d 篇' % (len(articles)))
for a in articles[:3]:
    print(a)

    
name=['title','summary','mark','response','href']
test=pd.DataFrame(columns=name,data=articles)
test.index = np.arange(1,len(test)+1)
test.index.names = ['article_NO.']
print(test)

test.to_csv('dcardcsv.csv',encoding='utf_8_sig')
